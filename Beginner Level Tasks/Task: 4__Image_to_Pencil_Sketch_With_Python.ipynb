# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnilkhartode/LGMVIP-Data-Science/blob/README/Beginner%20Level%20Tasks/Task%3A%204__Image_to_Pencil_Sketch_With_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore Virtual Internship Program (November-2021)**
#
# **Beginner Level Task**
#
# **Name : Swapnil Ramesh Khartode**
#
# **Task 4 : Image to Pencil Sketch With Python**

# %% [markdown]
# **import libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
#  **Reading the image**

# %%
img = cv2.imread("/flower.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F81D0AEDE10>

# %% [markdown]
# **Converting image into GRAY SCALE IMAGE**

# %%
#convert image from BGR to gray scale image 
gray_scale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F81CF9491D0>

# %% [markdown]
#  **Inverting the gray scale image**

# %%
#using bitwise_not functn to invert the image
inverted_img = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F81CFA08FD0>

# %% [markdown]
#  **Image Smoothing**

# %%
#Used gaussian blur technique with 21 x 21 pixel and 
#the default sigma values filter on the image to smmoothen our image
img_smoothing = cv2.GaussianBlur(inverted_img, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F81CF9CAE50>

# %% [markdown]
#  **Final Pencil SKETCH**

# %%
#Dividing the grayscale values of the image by the inverse of blurred image value which highlights the boldest edges of the image
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_scale_image, img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F81CF949F50>

# %% [markdown]
#  **Both image comparison**

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F81D0A7BB50>
# <PIL.Image.Image image mode=L size=400x400 at 0x7F81D0A7B750>
